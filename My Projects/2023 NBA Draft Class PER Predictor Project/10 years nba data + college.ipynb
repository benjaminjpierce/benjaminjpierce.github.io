# %%
import pandas as pd

# NBA 2018 data in NBA
df_10_years_college = pd.read_csv('2009 to 2008 college data.txt')
df_10_years_college
# Out:
#      Unnamed: 0.1                   Player          team conf  GP  Min_per  \
# 0             112              Jordan Hill       Arizona  P10  34     86.3
# 1             113           Chase Budinger       Arizona  P10  35     93.7
# 2             152              Eric Maynor           VCU  CAA  34     88.0
# 3             190               Earl Clark    Louisville   BE  37     85.4
# 4             232         Dante Cunningham     Villanova   BE  38     78.6
# ..            ...                      ...           ...  ...  ..      ...
# 455         46216  Shai Gilgeous-Alexander      Kentucky  SEC  37     84.0
# 456         46242       Wendell Carter Jr.          Duke  ACC  37     66.6
# 457         46245        Jaren Jackson Jr.  Michigan St.  B10  35     54.4
# 458         46347        Jarred Vanderbilt      Kentucky  SEC  14     16.0
# 459         46348               Kevin Knox      Kentucky  SEC  37     80.7
#
#       Ortg   usg   eFG  TS_per  ...    oreb    dreb     treb     ast     stl  \
# 0    108.9  28.0  53.7   56.04  ...  4.2059  6.8235  11.0294  1.4706  0.8824
# 1    117.5  23.9  55.4   59.42  ...  1.4000  4.8000   6.2000  3.3714  1.4286
# 2    117.3  32.6  52.4   58.33  ...  0.4706  3.1176   3.5882  6.1765  1.7059
# 3    100.3  24.6  49.2   51.67  ...  2.7568  5.9459   8.7027  3.2162  1.0270
# 4    109.0  24.7  52.5   55.68  ...  2.6053  4.8684   7.4737  1.2368  1.2368
# ..     ...   ...   ...     ...  ...     ...     ...      ...     ...     ...
# 455  114.1  22.8  51.6   57.87  ...  0.8919  3.2432   4.1351  5.1081  1.6486
# 456  121.5  23.4  59.1   62.81  ...  2.9459  6.1081   9.0541  2.0000  0.8108
# 457  116.8  22.8  59.5   64.71  ...  1.4857  4.3143   5.8000  1.1143  0.6000
# 458  107.3  22.9  42.6   47.65  ...  3.2857  4.5714   7.8571  1.0000  0.4286
# 459  107.0  23.0  51.1   55.69  ...  0.8919  4.5135   5.4054  1.4324  0.8378
#
#         blk      pts  Unnamed: 64  Unnamed: 65  Unnamed: 0
# 0    1.7059  18.2647          NaN     0.000000           7
# 1    0.4571  18.0000          NaN     7.835620          43
# 2    0.1765  22.3529          NaN     9.088320          19
# 3    1.3784  14.1892          NaN     4.318680          13
# 4    1.2368  16.1053          NaN     0.095285          32
# ..      ...      ...          ...          ...         ...
# 455  0.4865  14.3784   Scoring PG     2.599240          10
# 456  2.0541  13.5405         PF/C     2.615120           6
# 457  3.0000  10.9143         PF/C     7.362530           3
# 458  0.7857   5.8571            C     0.239403          40
# 459  0.2703  15.6216       Wing F     7.926720           8
#
# [460 rows x 68 columns]

# %%
# read in the data
df_10_years_college = pd.read_csv('2009 to 2008 college data.txt')

# group the data by player name and calculate the mean of each group
df_average_college = df_10_years_college.groupby('Player').mean()

# reset index
df_average_college = df_average_college.reset_index()

df_average_college.to_csv('averaged_data.csv', index=False)
df_average_college
# Out:
#             Player  Unnamed: 0.1    GP  Min_per   Ortg   usg   eFG  TS_per  \
# 0     A.J. Hammons       32626.0  33.0     57.5  114.7  27.2  60.1   62.32
# 1       A.J. Price        4383.0  34.0     73.0  108.5  24.4  50.7   53.92
# 2     Aaron Gordon       25966.0  38.0     77.1  105.5  23.2  51.6   50.27
# 3    Aaron Holiday       42986.0  33.0     92.1  112.9  27.2  55.7   60.87
# 4      Aaron White       28267.0  34.0     78.1  128.1  23.0  55.3   63.26
# ..             ...           ...   ...      ...    ...   ...   ...     ...
# 442   Xavier Henry        7197.0  36.0     68.3  113.7  21.7  55.5   59.10
# 443  Xavier Thames       24130.0  34.0     79.6  120.0  28.3  47.4   55.56
# 444   Zach Collins       41498.0  39.0     43.1  120.6  24.8  67.6   70.32
# 445    Zach LaVine       26534.0  37.0     60.7  107.3  19.0  52.4   54.48
# 446   Zhaire Smith       46207.0  37.0     70.5  124.3  18.6  58.5   61.51
#
#      ORB_per  DRB_per  ...     dgbpm    oreb    dreb    treb     ast     stl  \
# 0       11.5     24.8  ...  4.607520  2.3333  5.8485  8.1818  1.1212  0.2727
# 1        2.1      9.2  ...  0.919770  0.5882  2.9706  3.5588  4.7059  0.6471
# 2       10.4     19.3  ...  3.852990  2.6842  5.2895  7.9737  1.9737  0.8947
# 3        1.6      8.7  ...  0.140775  0.5152  3.1515  3.6667  5.8182  1.2727
# 4        7.7     18.5  ...  3.205250  2.0882  5.2059  7.2941  1.4118  1.3235
# ..       ...      ...  ...       ...     ...     ...     ...     ...     ...
# 442      5.2     11.5  ...  2.477540  1.1944  3.1667  4.3611  1.4722  1.5000
# 443      2.1      8.7  ...  4.344120  0.5882  2.3529  2.9412  3.2647  1.6471
# 444     12.2     23.2  ...  5.664370  1.6923  4.2051  5.8974  0.4103  0.4615
# 445      2.4      9.5  ...  0.535932  0.4865  2.0541  2.5405  1.7838  0.8919
# 446      9.1     11.2  ...  3.927380  2.1351  2.7568  4.8919  1.7297  1.1622
#
#         blk      pts  Unnamed: 65  Unnamed: 0
# 0    2.5455  14.9697     0.795572        45.0
# 1    0.0000  14.5882    10.516700        51.0
# 2    1.0263  12.3684     2.350110         3.0
# 3    0.2424  20.3333     9.191700        22.0
# 4    0.4706  16.4118     3.412010        48.0
# ..      ...      ...          ...         ...
# 442  0.5000  13.4167     9.149420        11.0
# 443  0.1471  18.1765     8.956100        58.0
# 444  1.7692  10.0000     1.747390         9.0
# 445  0.1622   9.4324     8.061630        12.0
# 446  1.0270  11.2162     2.232800        15.0
#
# [447 rows x 62 columns]

# %%
# from 2013 to 2022
df_4_years_after = pd.read_csv('nba10years.txt')

# group the data by player name and calculate the mean of each group
df_average_nba = df_4_years_after.groupby('Player').mean()

# reset index
df_average_nba = df_4_years_after.reset_index()

df_average_nba.to_csv('nba_advanced_stats_4_years_later.csv', index=False)
df_average_nba
# Out:
#      index  Unnamed: 0.1   Rk             Player Pos  Age   Tm   G    MP  \
# 0        0            32   23         Jeff Ayres  PF   25  IND  37   369
# 1        1            51   40  Rodrigue Beaubois  PG   24  DAL  45   549
# 2        2            54   42   Patrick Beverley  PG   24  HOU  41   713
# 3        3            58   46       DeJuan Blair  PF   23  SAS  61   851
# 4        4            82   65     Chase Budinger  SF   24  MIN  23   508
# ..     ...           ...  ...                ...  ..  ...  ...  ..   ...
# 430    430           697  504    Anfernee Simons  SG   22  POR  57  1681
# 431    431           764  547     Gary Trent Jr.  SG   23  TOR  70  2448
# 432    432           774  553  Jarred Vanderbilt  PF   22  MIN  74  1880
# 433    433           818  589    Robert Williams   C   24  BOS  61  1804
# 434    434           838  602         Trae Young  PG   23  ATL  76  2652
#
#       PER  ...  OWS  DWS    WS  WS/48  Unnamed: 24  OBPM  DBPM  BPM  VORP  \
# 0    14.5  ...  0.3  0.7   1.0  0.129          NaN  -1.9   0.9 -1.0   0.1
# 1    10.6  ...  0.0  0.4   0.4  0.032          NaN  -2.3  -0.3 -2.6  -0.1
# 2    15.4  ...  1.4  0.8   2.2  0.148          NaN   1.7   2.1  3.8   1.0
# 3    14.6  ...  0.7  1.5   2.2  0.126          NaN  -2.4   0.8 -1.6   0.1
# 4    12.6  ...  0.3  0.4   0.7  0.066          NaN  -0.6  -0.8 -1.4   0.1
# ..    ...  ...  ...  ...   ...    ...          ...   ...   ...  ...   ...
# 430  15.3  ...  2.0 -0.1   1.9  0.055          NaN   1.9  -2.7 -0.7   0.5
# 431  14.7  ...  3.1  2.5   5.6  0.110          NaN  -0.1   0.3  0.2   1.3
# 432  15.3  ...  3.1  2.9   6.0  0.153          NaN  -0.8   1.0  0.2   1.1
# 433  22.1  ...  6.0  3.9   9.9  0.262          NaN   2.4   3.1  5.5   3.4
# 434  25.4  ...  9.0  1.0  10.0  0.181          NaN   7.1  -2.0  5.2   4.8
#
#      Unnamed: 0
# 0            30
# 1            24
# 2            41
# 3            36
# 4            43
# ..          ...
# 430          23
# 431          36
# 432          40
# 433          26
# 434           4
#
# [435 rows x 32 columns]

# %%
df_10_years_clean_nba = df_average_nba[['Player', 'PER']]

# %%
df_10_years_final = pd.merge(df_10_years_clean_nba, df_10_years_college, on='Player', how='outer')
df_10_years_final.to_csv('df_10_years_final.csv', index=False)

df_10_years_final.drop('Unnamed: 64', axis=1, inplace=True)
df_10_years_final.drop('Unnamed: 65', axis=1, inplace=True)
df_10_years_final.drop('Unnamed: 0.1', axis=1, inplace=True)
df_10_years_final.drop('Unnamed: 0', axis=1, inplace=True)


# removes row  if PER has no value
df_10_years_final.dropna(how='any', inplace=True)




df_10_years_final
# Out:
#                 Player   PER            team  conf    GP  Min_per   Ortg  \
# 50     Marcus Thornton  16.3  William & Mary   CAA  31.0     93.2  111.7
# 53        Cole Aldrich  19.1          Kansas   B12  36.0     66.4  116.9
# 54     Al-Farouq Aminu  13.2     Wake Forest   ACC  31.0     76.4  101.8
# 55      James Anderson  10.9    Oklahoma St.   B12  33.0     84.8  117.5
# 57        Luke Babbitt  12.1          Nevada   WAC  33.0     93.2  120.4
# ..                 ...   ...             ...   ...   ...      ...    ...
# 453      Collin Sexton  11.2         Alabama   SEC  33.0     68.6  109.6
# 454      Landry Shamet  10.2     Wichita St.  Amer  32.0     76.3  127.5
# 456     Gary Trent Jr.  14.7            Duke   ACC  37.0     83.8  122.3
# 457  Jarred Vanderbilt  15.3        Kentucky   SEC  14.0     16.0  107.3
# 458    Robert Williams  22.1       Texas A&M   SEC  30.0     54.9  111.4
#
#       usg   eFG  TS_per  ...       mp    ogbpm     dgbpm    oreb    dreb  \
# 50   27.2  55.6   59.66  ...  36.6667  4.77995 -3.481520  0.2727  2.5152
# 53   20.2  56.2   59.61  ...  26.7500  4.63956  5.165330  3.0556  6.7778
# 54   27.8  47.1   52.40  ...  31.2903  4.27468  2.154910  4.2903  6.4194
# 55   30.7  53.2   59.61  ...  34.0606  9.42410  1.881250  1.9394  3.8788
# 57   26.0  54.0   61.23  ...  37.5455  6.51045  0.568331  2.0606  6.8182
# ..    ...   ...     ...  ...      ...      ...       ...     ...     ...
# 453  32.5  49.8   56.66  ...  29.9394  5.21146  0.629587  1.0303  2.7273
# 454  21.0  62.2   65.54  ...  31.7188  7.29565  0.363400  0.4375  2.7812
# 456  17.3  52.8   56.65  ...  33.7568  3.98383  1.863630  0.8378  3.4054
# 457  22.9  42.6   47.65  ...  17.0000  3.02946  2.021200  3.2857  4.5714
# 458  19.3  63.2   61.40  ...  25.6333  4.16384  5.445540  2.3667  6.8667
#
#         treb     ast     stl     blk      pts
# 50    2.7879  2.8788  0.6364  0.1212  19.9697
# 53    9.8333  0.8611  0.7500  3.4722  11.2778
# 54   10.7097  1.3226  1.4194  1.4194  15.8387
# 55    5.8182  2.4242  1.3939  0.6061  22.2727
# 57    8.8788  2.1212  1.0000  0.7879  22.0303
# ..       ...     ...     ...     ...      ...
# 453   3.7576  3.6061  0.8485  0.0909  19.1515
# 454   3.2188  5.1875  0.7188  0.1875  14.9062
# 456   4.2432  1.4054  1.1622  0.1351  14.4865
# 457   7.8571  1.0000  0.4286  0.7857   5.8571
# 458   9.2333  1.4333  0.8000  2.5000  10.3667
#
# [317 rows x 65 columns]
